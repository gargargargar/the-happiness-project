# %%
import pandas as pd

# %%
path = "../datasets/raw-dataset.csv"
df = pd.read_csv(path,usecols=["Country Name","Indicator Name","2015"])
df_tidy = df.pivot(values = "2015",index = "Country Name",columns = "Indicator Name")
df_tidy = df_tidy[[c for c in df_tidy if df_tidy[c].isnull().sum() < 20]]

# %%
path2 = "../datasets/dataset-top-features-2015.csv"
df2 = pd.read_csv(path2,usecols=["Country","Happiness Score"])
df2015 = pd.merge(left=df_tidy, right=df2, left_on = "Country Name", right_on = "Country")

# %%
path = "../datasets/raw-dataset.csv"
df = pd.read_csv(path,usecols=["Country Name","Indicator Name","2016"])
df_tidy = df.pivot(values = "2016",index = "Country Name",columns = "Indicator Name")
df_tidy = df_tidy[[c for c in df_tidy if df_tidy[c].isnull().sum() < 20]]

# %%
path2 = "../datasets/dataset-top-features-2016.csv"
df2 = pd.read_csv(path2,usecols=["Country","Happiness Score"])
df2016 = pd.merge(left=df_tidy, right=df2, left_on = "Country Name", right_on = "Country")

# %%
path = "../datasets/raw-dataset.csv"
df = pd.read_csv(path,usecols=["Country Name","Indicator Name","2017"])
df_tidy = df.pivot(values = "2017",index = "Country Name",columns = "Indicator Name")
df_tidy = df_tidy[[c for c in df_tidy if df_tidy[c].isnull().sum() < 20]]

# %%
path2 = "../datasets/dataset-top-features-2017.csv"
df2 = pd.read_csv(path2,usecols=["Country","Happiness Score"])
df2017 = pd.merge(left=df_tidy, right=df2, left_on = "Country Name", right_on = "Country")

# %%
df2015
# Out:
#      Access to electricity (% of population)  \
# 0                                  71.500000
# 1                                 100.000000
# 2                                  99.943069
# 3                                  42.000000
# 4                                  99.823578
# ..                                       ...
# 133                                99.709480
# 134                                99.998055
# 135                               100.000000
# 136                                31.100000
# 137                                33.700000
#
#      Access to electricity, rural (% of rural population)  \
# 0                                            64.573354
# 1                                           100.000000
# 2                                            99.817895
# 3                                             3.815066
# 4                                            98.169617
# ..                                                 ...
# 133                                         100.000000
# 134                                          99.996050
# 135                                         100.000000
# 136                                           4.697573
# 137                                          10.949313
#
#      Access to electricity, urban (% of urban population)  \
# 0                                            92.500000
# 1                                           100.000000
# 2                                            99.994575
# 3                                            64.000000
# 4                                            99.977165
# ..                                                 ...
# 133                                          99.806205
# 134                                         100.000000
# 135                                         100.000000
# 136                                          67.700000
# 137                                          81.200000
#
#      Adjusted savings: carbon dioxide damage (current US$)  \
# 0                                         3.541553e+08
# 1                                         1.772066e+08
# 2                                         4.604937e+09
# 3                                         1.059179e+09
# 4                                         6.264905e+09
# ..                                                 ...
# 133                                       1.989705e+08
# 134                                       3.124129e+09
# 135                                       5.402098e+09
# 136                                       1.419430e+08
# 137                                       3.535288e+08
#
#      Adjusted savings: energy depletion (current US$)  \
# 0                                        9.141181e+06
# 1                                        1.051179e+08
# 2                                        1.657772e+10
# 3                                        9.287312e+09
# 4                                        4.693623e+09
# ..                                                ...
# 133                                      0.000000e+00
# 134                                      2.605462e+09
# 135                                      2.204875e+09
# 136                                      2.938739e+05
# 137                                      2.844363e+07
#
#      Adjusted savings: mineral depletion (current US$)  \
# 0                                         8.107718e+05
# 1                                         1.675532e+07
# 2                                         8.894662e+06
# 3                                         0.000000e+00
# 4                                         1.278704e+09
# ..                                                 ...
# 133                                       3.380577e+07
# 134                                       2.241901e+09
# 135                                       2.400252e+08
# 136                                       1.607302e+09
# 137                                       4.769760e+08
#
#      Agricultural land (% of land area)  Agricultural land (sq. km)  \
# 0                             58.067580                3.791000e+05
# 1                             42.857666                1.174300e+04
# 2                             17.405929                4.145640e+05
# 3                             47.477340                5.919000e+05
# 4                             54.335712                1.487000e+06
# ..                                  ...                         ...
# 133                           82.559705                1.444960e+05
# 134                           62.929008                2.677000e+05
# 135                           39.255652                1.217200e+05
# 136                           32.063923                2.383600e+05
# 137                           41.876696                1.620000e+05
#
#      Arable land (% of land area)  Arable land (hectares per person)  ...  \
# 0                       11.893821                           0.225638  ...
# 1                       22.448904                           0.213524  ...
# 2                        3.133046                           0.187830  ...
# 3                        3.930376                           0.175726  ...
# 4                       14.323873                           0.908839  ...
# ..                            ...                                ...  ...
# 133                     13.773284                           0.706505  ...
# 134                     10.343206                           0.140580  ...
# 135                     22.569097                           0.075510  ...
# 136                      5.111718                           0.239304  ...
# 137                     10.339925                           0.289548  ...
#
#      Secure Internet servers (per 1 million people)  Surface area (sq. km)  \
# 0                                          2.150312               652860.0
# 1                                         68.386085                28750.0
# 2                                          3.826015              2381740.0
# 3                                          8.140758              1246700.0
# 4                                        123.272841              2780400.0
# ..                                              ...                    ...
# 133                                      186.107364               176220.0
# 134                                        5.655151               447400.0
# 135                                       32.726540               331230.0
# 136                                        5.667734               752610.0
# 137                                       11.726699               390760.0
#
#      Total fisheries production (metric tons)  \
# 0                                     2150.00
# 1                                     9472.50
# 2                                    97278.99
# 3                                   496104.00
# 4                                   817962.70
# ..                                        ...
# 133                                  59743.83
# 134                                  59852.40
# 135                                6207514.00
# 136                                 106473.00
# 137                                  25500.00
#
#      Total natural resources rents (% of GDP)  \
# 0                                    0.479033
# 1                                    1.813210
# 2                                   16.249189
# 3                                   10.803628
# 4                                    1.336710
# ..                                        ...
# 133                                  1.714124
# 134                                 10.719355
# 135                                  3.284043
# 136                                 16.187354
# 137                                  6.698087
#
#      Tuberculosis case detection rate (%, all forms)  Urban population  \
# 0                                               55.0         8535606.0
# 1                                               87.0         1654503.0
# 2                                               80.0        28146511.0
# 3                                               58.0        17691524.0
# 4                                               87.0        39467043.0
# ..                                               ...               ...
# 133                                             87.0         3242944.0
# 134                                             67.0        15884192.0
# 135                                             55.0        31333193.0
# 136                                             59.0         6654564.0
# 137                                             81.0         4473868.0
#
#      Urban population (% of total population)  \
# 0                                      24.803
# 1                                      57.434
# 2                                      70.848
# 3                                      63.446
# 4                                      91.503
# ..                                        ...
# 133                                    95.045
# 134                                    50.750
# 135                                    33.809
# 136                                    41.907
# 137                                    32.385
#
#      Urban population growth (annual %)      Country  Happiness Score
# 0                              3.951762  Afghanistan            3.575
# 1                              1.484764      Albania            4.959
# 2                              2.934320      Algeria            5.605
# 3                              4.572192       Angola            4.033
# 4                              1.215797    Argentina            6.574
# ..                                  ...          ...              ...
# 133                            0.445092      Uruguay            6.485
# 134                            1.547412   Uzbekistan            6.003
# 135                            3.118033      Vietnam            5.360
# 136                            4.327561       Zambia            5.129
# 137                            1.297036     Zimbabwe            4.610
#
# [138 rows x 109 columns]

# %%
df2016.columns
# Out:
# Index(['Access to electricity (% of population)',
#        'Access to electricity, rural (% of rural population)',
#        'Access to electricity, urban (% of urban population)',
#        'Adjusted savings: carbon dioxide damage (current US$)',
#        'Adjusted savings: energy depletion (current US$)',
#        'Adjusted savings: mineral depletion (current US$)',
#        'Agricultural land (% of land area)', 'Agricultural land (sq. km)',
#        'Arable land (% of land area)', 'Arable land (hectares per person)',
#        ...
#        'Terrestrial and marine protected areas (% of total territorial area)',
#        'Terrestrial protected areas (% of total land area)',
#        'Total fisheries production (metric tons)',
#        'Total natural resources rents (% of GDP)',
#        'Tuberculosis case detection rate (%, all forms)', 'Urban population',
#        'Urban population (% of total population)',
#        'Urban population growth (annual %)', 'Country', 'Happiness Score'],
#       dtype='object', length=104)

# %%
dfnew = df2016.append(df2015)
# Out:
# C:\Users\garga\Anaconda3\lib\site-packages\pandas\core\frame.py:7123: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,

# %%
dfnew = dfnew.append(df2017)

# %%
dfnew
# Out:
#      Access to electricity (% of population)  \
# 0                                  97.700000
# 1                                 100.000000
# 2                                  99.992317
# 3                                  40.624527
# 4                                  99.966881
# ..                                       ...
# 133                               100.000000
# 134                               100.000000
# 135                               100.000000
# 136                                40.300000
# 137                                40.421368
#
#      Access to electricity, rural (% of rural population)  \
# 0                                            97.099360
# 1                                           100.000000
# 2                                            99.973082
# 3                                             0.000000
# 4                                            99.732692
# ..                                                 ...
# 133                                         100.000000
# 134                                         100.000000
# 135                                         100.000000
# 136                                          13.997701
# 137                                          18.934611
#
#      Access to electricity, urban (% of urban population)  \
# 0                                            99.500000
# 1                                           100.000000
# 2                                           100.000000
# 3                                            70.794960
# 4                                            99.988281
# ..                                                 ...
# 133                                         100.000000
# 134                                         100.000000
# 135                                         100.000000
# 136                                          75.200000
# 137                                          85.587082
#
#      Adjusted savings: carbon dioxide damage (current US$)  \
# 0                                         4.427148e+08
# 1                                         1.907652e+08
# 2                                         4.977417e+09
# 3                                         1.066588e+09
# 4                                         6.321202e+09
# ..                                                 ...
# 133                                       2.147635e+08
# 134                                       3.211032e+09
# 135                                       6.697287e+09
# 136                                       1.711111e+08
# 137                                       3.730322e+08
#
#      Adjusted savings: energy depletion (current US$)  \
# 0                                        1.248047e+07
# 1                                        6.420515e+07
# 2                                        1.207529e+10
# 3                                        7.913822e+09
# 4                                        3.245040e+09
# ..                                                ...
# 133                                      0.000000e+00
# 134                                      2.381001e+09
# 135                                      1.861265e+09
# 136                                      8.826167e+05
# 137                                      3.132278e+07
#
#      Adjusted savings: mineral depletion (current US$)  \
# 0                                         9.110295e+05
# 1                                         1.442392e+06
# 2                                         9.186936e+06
# 3                                         0.000000e+00
# 4                                         1.346216e+09
# ..                                                 ...
# 133                                       2.180021e+07
# 134                                       2.465483e+09
# 135                                       2.543524e+08
# 136                                       2.074379e+09
# 137                                       5.871563e+08
#
#      Agricultural land (% of land area)  Agricultural land (sq. km)  \
# 0                             58.067580                3.791000e+05
# 1                             43.127735                1.181700e+04
# 2                             17.365539                4.136020e+05
# 3                             47.477340                5.919000e+05
# 4                             54.335712                1.487000e+06
# ..                                  ...                         ...
# 133                                 NaN                         NaN
# 134                                 NaN                         NaN
# 135                                 NaN                         NaN
# 136                                 NaN                         NaN
# 137                                 NaN                         NaN
#
#      Arable land (% of land area)  Arable land (hectares per person)  ...  \
# 0                       11.838679                           0.218437  ...
# 1                       22.638686                           0.215674  ...
# 2                        3.108736                           0.182588  ...
# 3                        3.930376                           0.169888  ...
# 4                       14.323873                           0.899281  ...
# ..                            ...                                ...  ...
# 133                           NaN                                NaN  ...
# 134                           NaN                                NaN  ...
# 135                           NaN                                NaN  ...
# 136                           NaN                                NaN  ...
# 137                           NaN                                NaN  ...
#
#      Secure Internet servers (per 1 million people)  Surface area (sq. km)  \
# 0                                         12.039637               652860.0
# 1                                        144.640261                28750.0
# 2                                          7.619958              2381740.0
# 3                                          8.321059              1246700.0
# 4                                        735.024765              2780400.0
# ..                                              ...                    ...
# 133                                     1103.692379               176220.0
# 134                                      202.169899               447400.0
# 135                                     1348.715951               331230.0
# 136                                       42.364615               752610.0
# 137                                       30.554737               390760.0
#
#      Terrestrial and marine protected areas (% of total territorial area)  \
# 0                                             0.104707
# 1                                            13.147749
# 2                                             7.105500
# 3                                             5.004713
# 4                                             7.528593
# ..                                                 ...
# 133                                           2.295077
# 134                                           3.375214
# 135                                           2.929507
# 136                                          37.870010
# 137                                          27.214585
#
#     Terrestrial protected areas (% of total land area)  \
# 0                                             0.100000
# 1                                            17.210000
# 2                                             7.500000
# 3                                             6.970000
# 4                                             8.890000
# ..                                                 ...
# 133                                           3.446202
# 134                                           3.375214
# 135                                           7.576780
# 136                                          37.870010
# 137                                          27.214585
#
#      Total fisheries production (metric tons)  \
# 0                                      2200.0
# 1                                      8835.7
# 2                                     96361.0
# 3                                    487145.0
# 4                                    758899.5
# ..                                        ...
# 133                                       NaN
# 134                                       NaN
# 135                                       NaN
# 136                                       NaN
# 137                                       NaN
#
#      Total natural resources rents (% of GDP)  \
# 0                                    0.625860
# 1                                    1.049503
# 2                                   12.303407
# 3                                   10.746210
# 4                                    1.134939
# ..                                        ...
# 133                                       NaN
# 134                                       NaN
# 135                                       NaN
# 136                                       NaN
# 137                                       NaN
#
#      Tuberculosis case detection rate (%, all forms)  Urban population  \
# 0                                               63.0         8852859.0
# 1                                               87.0         1680247.0
# 2                                               80.0        28977628.0
# 3                                               57.0        18502165.0
# 4                                               87.0        39940546.0
# ..                                               ...               ...
# 133                                             87.0         3273062.0
# 134                                             72.0        16372437.0
# 135                                             58.0        33310316.0
# 136                                             59.0         7243041.0
# 137                                             82.0         4589499.0
#
#      Urban population (% of total population)  \
# 0                                      25.020
# 1                                      58.421
# 2                                      71.459
# 3                                      64.149
# 4                                      91.627
# ..                                        ...
# 133                                    95.240
# 134                                    50.550
# 135                                    35.213
# 136                                    42.976
# 137                                    32.237
#
#      Urban population growth (annual %)
# 0                              3.649410
# 1                              1.544014
# 2                              2.910068
# 3                              4.480210
# 4                              1.192603
# ..                                  ...
# 133                            0.465663
# 134                            1.485878
# 135                            3.034416
# 136                            4.211349
# 137                            1.277192
#
# [414 rows x 113 columns]

# %%
from sklearn.model_selection import train_test_split
df.fillna(df.mean(), inplace=True)
X_train,X_test,y_train,y_test = train_test_split(dfnew[dfnew.drop(["Happiness Score","Country"],axis = 1).columns],dfnew["Happiness Score"],test_size=0.2,random_state = 42)

# %%
from sklearn.linear_model import Lasso
lasso = Lasso(alpha=0.1)
lasso.fit(X_train,y_train)
lasso_pred = lasso.predict(X_test)
score = lasso.score(X_test,y_test)

# %% [raw]
# score

# %%
score

# %%
score

# %%
score

# %%
score

# %%
score

# %%
import matplotlib.pyplot as plt
name = X_train.columns
lasso_coef = lasso.fit(X_train,y_train).coef_
plt.plot(range(len(name)), lasso_coef)
plt.xticks(range(len(name)), name.values,rotation = 60)
plt.margins(0.02)
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
plt.show()
plt.savefig('fig.png')

# %%
mydict = {}

# %%
for index,items in enumerate(lasso_coef):
   mydict[items] = name[index]

# %%
mydict

# %%
lasso_coef.sort()

# %%
mylist = []
for items in lasso_coef:
        mylist.append(mydict[items])

# %%
mylist.reverse()

# %%
mylist
